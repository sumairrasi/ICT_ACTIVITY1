# %% [markdown]
# ## 1. Complete the following code to find the area of an equilateral triangle. Output should be as displayed

# %%
import math
side = float(input("Enter the side of the equilateral triangle: "))
area = ((math.sqrt(3))/4)*pow(side,2)
print("Area of quilateral triangle",area)
# Out:
# Enter the side of the equilateral triangle: 5
# Area of quilateral triangle 10.825317547305483

# %% [markdown]
# ## 2. Write a program to count the number of each characters in a string

# %%
count=0
chara=input("Enter the words:\n")
for i in chara:
    if i==" ":
     continue
    count+=1
print(count)
# Out:
# Enter the words:
# Hello world
# 10

# %% [markdown]
# ## 3. Write a program to find the area and perimeter of a rectangle using functions

# %%
def perimeter(l,b):
    return(2*(l+b))
    
def Area(l,b):
    return(2*(l*b))
    
length=int(input("Enter length:"))
bredth=int(input("Enter bredth:"))

print("perimeter of rectangle",perimeter(length,bredth))
print("Area of rectangle",Area(length,bredth))
# Out:
# Enter length:5
# Enter bredth:4
# perimeter of rectangle 18
# Area of rectangle 40

# %% [markdown]
# ## 4. Write a program to print the fibonacci series till a specified number

# %%
num=int(input("Enter the fibanacci number:"))
if num>0:
  a=0
  b=1
  print(a)
  print(b)
  for i in range(0,num-1):
    sum=a+b
    a=b
    b=sum
    print(sum)
# Out:
# Enter the fibanacci number:8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# ## 5. Complete the following code to find the minimum of 3 number using conditional statements. Output should be as displayed

# %%
a,b,c = input("Enter three numbers followed by  : ").split()

print("First number :",a)
print("Second number :",b)
print("Third number :",c)

if a==b==c: 
    print("Entered numbers are equal!!!")
elif a<b and a<c:
    print(a," is smallest")
elif b<a and b<c:
    print(b," is smallest")
else:
    print(c," is smallest")
# Out:
# Enter three numbers followed by  : 5 3 2
# First number : 5
# Second number : 3
# Third number : 2
# 2  is smallest

# %% [markdown]
# ## 6. Write a program to print star pyramind. The number of rows should be taken as input from the user

# %%
n=int(input("Enter the number"))
k=n-1

for i in range(0,n):
    for j in range(0,k):
        print(end=" ")
    k=k-1
    for j in range(0,i+1):
        print("*",end=" ")
    print("\r")
# Out:
# Enter the number5
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %% [markdown]
# ## 7. Complete the following code to convert hour into seconds. Output should be as displayed

# %%
def to_seconds(t):
    t=(60**2)*time_in_hours
    return t
time_in_hours = int(input("Enter time in Hours:"))
print(time_in_hours ," Hour is equal to" ,to_seconds(time_in_hours) ," Seconds")
# Out:
# Enter time in Hours:5
# 5  Hour is equal to 18000  Seconds

# %% [markdown]
# ## 8. Write a program to print multiplication table as below

# %%
num=int(input("Enter the multiplication number:"))
for i in range(1,11):
    print(i,"*",num,"=",i*num)
# Out:
# Enter a number to find the multiplication table: 67
# 1 x 67 = 67
# 2 x 67 = 134
# 3 x 67 = 201
# 4 x 67 = 268
# 5 x 67 = 335
# 6 x 67 = 402
# 7 x 67 = 469
# 8 x 67 = 536
# 9 x 67 = 603
# 10 x 67 = 670

# %% [markdown]
# ## 9. Write a program to take your 5 favorite food as list and print each as 'I like Biriyani'

# %%
fav=[]
for i in range(0,5):
    food=input("eneter your favourate food")
    fav.append(food)
print(fav)
for j in fav:
    print("I like",j)
# Out:
# eneter your favourate foodpizza
# eneter your favourate foodburger
# eneter your favourate foodkuzhi mandhi
# eneter your favourate foodnoodles
# eneter your favourate foodwaffels
# ['pizza', 'burger', 'kuzhi mandhi', 'noodles', 'waffels']
# I like pizza
# I like burger
# I like kuzhi mandhi
# I like noodles
# I like waffels
